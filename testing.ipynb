# %%
properties = {
        'name': 'hasib',
        'architecture': 'amd64',
        'os': 'linux',
        'kernel': '5.15.0-87-generic',
        'memory': 45763298
    }

# %%
kwargs = {
        'aglkj': 'lajf',
        'la;gj': 'lskjf',
    }

# %%
placeholders = ', '.join([f'{key}: ${key}' for key in properties.keys()])
placeholders += ', '
placeholders += ', '.join([f'{key}: ${key}' for key in kwargs.keys()])
placeholders
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/ubuntu/dev/app/kubegrapher/kubegrapher/testing.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2B10.18.1.40/home/ubuntu/dev/app/kubegrapher/kubegrapher/testing.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> kwargs = None
# ----> <a href='vscode-notebook-cell://ssh-remote%2B10.18.1.40/home/ubuntu/dev/app/kubegrapher/kubegrapher/testing.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> placeholders = ', '.join([f'{key}: ${key}' for key in properties.keys()])
#       <a href='vscode-notebook-cell://ssh-remote%2B10.18.1.40/home/ubuntu/dev/app/kubegrapher/kubegrapher/testing.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> placeholders += ', '
# ...
